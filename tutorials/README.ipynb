# %% [markdown]
# # VEClim – Tutorials
#
# Welcome to VEClim's tutorial set!
#
# ## Available Notebooks
#
# - [Nicosia2025 Tutorials](Nicosia2025/README.ipynb)
#
# ---
#
# Click any notebook to open it.
